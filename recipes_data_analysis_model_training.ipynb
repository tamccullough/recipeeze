# %% [markdown]
# ### recipeeze
# * Contributors
#     * Todd McCullough [Git](https://github.com/tamccullough)
#     * Marko Topitch [Git](https://github.com/TopMarko)

# %%
import pandas as pd
import numpy as np
import heapq
import random
from math import floor

# %% [markdown]
# ##### Import Surprise
# [Surprise](http://surpriselib.com/) is a Python scikit building and analyzing recommender systems that deal with explicit rating data.

# %%
from surprise import Reader, Dataset
from surprise import KNNWithMeans
from surprise.model_selection import cross_validate

# %% [markdown]
# import pickle
# filename = 'model/recipes_recommender_model.sav'
# rr_model = pickle.load(open(filename, 'rb'))

# %% [markdown]
# ##### Import Data

# %%
recipes = pd.read_csv('datasets/rr-recipes.csv')
ratings = pd.read_csv('datasets/rr-ratings.csv')

# %%
ratings.head(2)
# Out:
#     userid  itemid  rating
# 0   675719    7000       5
# 1  1478626    7000       5

# %%
ratings.shape
# Out:
# (1555581, 3)

# %%
recipes.head(2)
# Out:
#    itemid                               title  prep_time  cook_time  \
# 0    7000        Golden Crescent Rolls Recipe         25         15
# 1    7001  Poppy Seed Bread with Glaze Recipe         15         60
#
#    ready_time                                        ingredients  \
# 0         190  yeast,water,white sugar,salt,egg,butter,flour,...
# 1          80  flour,salt,baking powder,poppy,butter,vegetabl...
#
#                                           directions  \
# 0  Dissolve yeast in warm water.**Stir in sugar, ...
# 1  'Preheat oven to 350 degrees F (175 degrees C)...
#
#                                       url  \
# 0  https://www.allrecipes.com/recipe/7000
# 1  https://www.allrecipes.com/recipe/7001
#
#                                            photo_url
# 0  https://images.media-allrecipes.com/userphotos...
# 1  https://images.media-allrecipes.com/userphotos...

# %%
ingredients = pd.DataFrame(recipes.ingredients,columns=['ingredients'])
ingredients['count'] = 1

# %%
ingredients_g = ingredients.groupby('ingredients').count().reset_index()
ingredients_g = ingredients_g.sort_values('count', ascending=False)
ingredients_g.head(5)
# Out:
#                                             ingredients  count
# 3765                                chocolate,chocolate      4
# 5922                        flour,salt,shortening,water      4
# 4441                           cream cheese,marshmallow      3
# 4277  cranberry,marshmallow,white sugar,pineapple,ba...      3
# 5642  flour,brown sugar,white sugar,pumpkin,vegetabl...      3

# %%
min_recipe_ratings = 150
filter_recipes = ratings['itemid'].value_counts() > min_recipe_ratings
filter_recipes = filter_recipes[filter_recipes].index.tolist()

min_user_ratings = 150
filter_users = ratings['userid'].value_counts() > min_user_ratings
filter_users = filter_users[filter_users].index.tolist()

ratings = ratings[(ratings['itemid'].isin(filter_recipes)) & (ratings['userid'].isin(filter_users))]
ratings.shape
# Out:
# (28806, 3)

# %%
users = ratings.userid.unique()

# %%
users.shape
# Out:
# (177,)

# %%
ratings.to_csv('datasets/ratings-s.csv',index=False)

# %% [markdown]
# ##### Define a Ratings scale
# This scale is determined by the lowest and highest rating possible.
# In this case the lowest rating is 1, while the highest is 5.

# %%
reader = Reader(rating_scale=(1,5)) # This just defines the rating scale
data = Dataset.load_from_df(ratings[['userid', 'itemid', 'rating']], reader=reader)

# %% [markdown]
# ### Build the model
#
# ##### KNN with Means - Surprise
#
# [KNN with Means](https://surprise.readthedocs.io/en/stable/knn_inspired.html#surprise.prediction_algorithms.knns.KNNWithMeans) has been chosen for the recommender, which is a basic collaborative filtering algorithm, taking into account the mean ratings of each user.

# %%
def build_recommender(user_based=False, sim_type='cosine'):
    sim_options = {
        "name": sim_type,
        "user_based": user_based
    }

    return KNNWithMeans(sim_options=sim_options)

# %% [markdown]
# ##### Calculate the Similarity Matrix
#
# Ignoring folds this builds the *Trainset* using [build_full_trainset()](https://surprise.readthedocs.io/en/stable/dataset.html#surprise.dataset.DatasetAutoFolds.build_full_trainset)
#
# The Trainset is built using the data, but then contains more information about the data

# %%
trainset = data.build_full_trainset()
# user_based_recommender = build_recommender(user_based=True)
item_based_recommender = build_recommender()
# User based seems to give a memory error when fit, due to the much larger amount of users than recipes.
# user_based_recommender.fit(trainset)
item_based_recommender.fit(trainset)
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.

# %% [markdown]
# ### Evaluate the Model
#
# Using [cross_validation()](https://surprise.readthedocs.io/en/stable/model_selection.html#cross-validation) from surprise, we can quickly evaluate the model using a few metrics.

# %%
cross_validate(item_based_recommender, data, measures=['RMSE', 'MAE'], cv=5, verbose=True)
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.7786  0.7983  0.7911  0.7781  0.7697  0.7832  0.0102
# MAE (testset)     0.5880  0.5924  0.5921  0.5885  0.5825  0.5887  0.0036
# Fit time          2.70    2.79    2.77    2.67    2.94    2.77    0.09
# Test time         1.44    1.40    1.34    1.33    1.39    1.38    0.04
# {'test_rmse': array([0.77859872, 0.79828874, 0.79105398, 0.77809451, 0.76974811]),
#  'test_mae': array([0.58798199, 0.5924363 , 0.59214918, 0.58849602, 0.58246707]),
#  'fit_time': (2.7038283348083496,
#   2.788450002670288,
#   2.7651755809783936,
#   2.6735758781433105,
#   2.9410524368286133),
#  'test_time': (1.439561367034912,
#   1.400172472000122,
#   1.3377301692962646,
#   1.3348004817962646,
#   1.3919811248779297)}

# %% [markdown]
# ### Inference
#
# Here is the meat and potatoes(har) of the whole thing.

# %%
def get_r(user_id):
    # Select which system to use. Due to memory constraints, item based is the only viable option
    recommender_system = item_based_recommender
    # N will represent how many items to recommend
    N = 1000
    
    # The setting to a set and back to list is a failsafe.
    rated_items = list(set(ratings.loc[ratings['userid'] == user_id]['itemid'].tolist()))
    ratings_list = recipes['itemid'].values.tolist()
    reduced_ratings = ratings.loc[ratings['itemid'].isin(ratings_list)].copy()
    
    # Self explanitory name
    all_item_ids = list(set(reduced_ratings['itemid'].tolist()))
    
    # New_items just represents all the items not rated by the user
    new_items = [x for x in all_item_ids if x not in rated_items]
    
    # Estimate ratings for all unrated items
    predicted_ratings = {}
    for item_id in new_items:
        predicted_ratings[item_id] = recommender_system.predict(user_id, item_id).est
        pass
    
    # Get the item_ids for the top ratings
    recommended_ids = heapq.nlargest(N, predicted_ratings, key=predicted_ratings.get)
    recommended_ids = sorted(recommended_ids)
    
    # predicted_ratings
    recommended_df = recipes.loc[recipes['itemid'].isin(recommended_ids)].copy()
    #recommended_df.insert(1, 'pred_rating', np.zeros(len(recommended_ids)))
    recommended_df.insert(1, 'pred_rating', 0)
    
    # recommended_df = recipes.copy()
    for idx,item_id in enumerate(recommended_ids):
        recommended_df.iloc[idx, recommended_df.columns.get_loc('pred_rating')] = predicted_ratings[item_id]
        pass
    return recommended_df.head(N).sort_values('pred_rating', ascending=False)

# %%
def cap_str(item):
    string = item
    return string.capitalize()

def reg_frame(r_list,items):
    s_ = ''
    for i in items:
        j = i.strip()
        str_ = f'(?=.*{j})'
        s_ += str_
    s_
    r_list = r_list[r_list['ingredients'].str.contains(fr'^\b{s_}\b',regex=True)]
    return r_list

def set_up_ml(user_id,ingredient_list):
    recipe_list = get_r(user_id)
    items = ingredient_list.split(',')
    recipe_list = reg_frame(recipe_list,items)
    return recipe_list

# %% [markdown]
# ### Get a Recommendation Based on Ingredients
#
# The final code that will be impletented in a cleaner fashion through the browser interface.

# %%
ingredient_list = 'spinach,cheese'

# %%
user_1 = random.choice(users)#123711 # user with a medium amount of ratings
user_2 = random.choice(users)#15078 # user with the lowest number of ratings
user_3 = random.choice(users)#72315 # user with a lot of ratings

# %%
recommended_list_1 = set_up_ml(user_1,ingredient_list) # generate a list of recommendations for each user
recommended_list_2 = set_up_ml(user_2,ingredient_list)
recommended_list_3 = set_up_ml(user_3,ingredient_list)

# %%
def get_final_recommendation(list_1,list_2,list_3): # combine all recommendations
    recipe_recommendation = pd.DataFrame()
    recipe_recommendation = pd.concat([list_1,list_2,list_3]) # concat lists
    recipe_recommendation = recipe_recommendation.drop_duplicates(keep='first') # drop recommended duplicates of recipes
    recipe_recommendation = recipe_recommendation.sort_values('pred_rating',ascending=False) # sort by predicted rating
    recipe_recommendation.pop('pred_rating') # drop the rating column
    recipe_recommendation = recipe_recommendation.reset_index()
    recipe_recommendation.pop('index') # reset and pop the old index
    recipe_recommendation.pop('itemid')
    #recipe_recommendation['total time'] = recipe_recommendation['prep_time']+recipe_recommendation['cook_time']
    return recipe_recommendation

# %%
final_recommendation = get_final_recommendation(recommended_list_1,recommended_list_2,recommended_list_3)
final_recommendation
# Out:
#                                       title  prep_time  cook_time  ready_time  \
# 0           Crustless Spinach Quiche Recipe          0         30          50
# 1                     Spinach Quiche Recipe          0         60          70
# 2              Ham and Cheese Quiche Recipe          0         55          70
# 3                      Harvest Salad Recipe          0          0          15
# 4              Artichoke Spinach Dip Recipe          0         20          35
# 5              Ham and Cheese Quiche Recipe          0         55          70
# 6                     Spanakopita II Recipe          0         65          95
# 7           Crustless Spinach Quiche Recipe          0         30          50
# 8       Spinach and Tortellini Salad Recipe          0         15          30
# 9   Hot Artichoke and Spinach Dip II Recipe          0         25          40
# 10    Luscious Spinach Artichoke Dip Recipe          0         25          35
# 11                     Harvest Salad Recipe          0          0          15
# 12  Hot Artichoke and Spinach Dip II Recipe          0         25          40
# 13    Luscious Spinach Artichoke Dip Recipe          0         25          35
# 14                    Spinach Quiche Recipe          0         60          70
# 15                    Spanakopita II Recipe          0         65          95
# 16    Luscious Spinach Artichoke Dip Recipe          0         25          35
# 17                    Spanakopita II Recipe          0         65          95
# 18  Hot Artichoke and Spinach Dip II Recipe          0         25          40
# 19             Ham and Cheese Quiche Recipe          0         55          70
# 20      Spinach and Tortellini Salad Recipe          0         15          30
# 21     Hot Spinach and Artichoke Dip Recipe          0         20          30
# 22       Pizza Without the Red Sauce Recipe         15         20          35
# 23   Spanakopita (Greek Spinach Pie) Recipe          0         60          90
# 24       Pizza Without the Red Sauce Recipe         15         20          35
# 25     Hot Spinach and Artichoke Dip Recipe          0         20          30
# 26                    Spinach Quiche Recipe          0         60          70
# 27                     Harvest Salad Recipe          0          0          15
# 28      Spinach and Tortellini Salad Recipe          0         15          30
# 29       Pizza Without the Red Sauce Recipe         15         20          35
# 30     Hot Spinach and Artichoke Dip Recipe          0         20          30
# 31           Spinach Tortellini Soup Recipe          5         15          20
# 32             Artichoke Spinach Dip Recipe          0         20          35
# 33             Artichoke Spinach Dip Recipe          0         20          35
# 34          Florentine Artichoke Dip Recipe          0         25          35
# 35   Spanakopita (Greek Spinach Pie) Recipe          0         60          90
# 36          Florentine Artichoke Dip Recipe          0         25          35
# 37          Florentine Artichoke Dip Recipe          0         25          35
# 38               Spinach Pasta Salad Recipe          0         15         145
#
#                                           ingredients  \
# 0   vegetable oil,onion,spinach,egg,cheese,salt,bl...
# 1   spinach,green onion,egg,cottage cheese,cheddar...
# 2   flour,salt,1 cup half-and-half,egg,swiss chees...
# 3   walnut,spinach,cranberry,blue cheese,tomato,av...
# 4   butter,spinach,artichoke,cream cheese,sour cre...
# 5   flour,salt,1 cup half-and-half,egg,swiss chees...
# 6   vegetable oil,onion,spinach,dill,flour,cheese,...
# 7   vegetable oil,onion,spinach,egg,cheese,salt,bl...
# 8   cheese,spinach,parmesan,cherry,olive,salad dre...
# 9   cream cheese,mayonnaise,parmesan,cheese,garlic...
# 10  artichoke,spinach,sour cream,mayonnaise,cream ...
# 11  walnut,spinach,cranberry,blue cheese,tomato,av...
# 12  cream cheese,mayonnaise,parmesan,cheese,garlic...
# 13  artichoke,spinach,sour cream,mayonnaise,cream ...
# 14  spinach,green onion,egg,cottage cheese,cheddar...
# 15  vegetable oil,onion,spinach,dill,flour,cheese,...
# 16  artichoke,spinach,sour cream,mayonnaise,cream ...
# 17  vegetable oil,onion,spinach,dill,flour,cheese,...
# 18  cream cheese,mayonnaise,parmesan,cheese,garlic...
# 19  flour,salt,1 cup half-and-half,egg,swiss chees...
# 20  cheese,spinach,parmesan,cherry,olive,salad dre...
# 21  bacon,spinach,artichoke,cheese,parmesan,sour c...
# 22  butter,olive,garlic,tomato,basil,oregano,parme...
# 23  olive,onion,green onion,garlic,spinach,parsley...
# 24  butter,olive,garlic,tomato,basil,oregano,parme...
# 25  bacon,spinach,artichoke,cheese,parmesan,sour c...
# 26  spinach,green onion,egg,cottage cheese,cheddar...
# 27  walnut,spinach,cranberry,blue cheese,tomato,av...
# 28  cheese,spinach,parmesan,cherry,olive,salad dre...
# 29  butter,olive,garlic,tomato,basil,oregano,parme...
# 30  bacon,spinach,artichoke,cheese,parmesan,sour c...
# 31   spinach,chicken broth,cheese,basil,garlic,pepper
# 32  butter,spinach,artichoke,cream cheese,sour cre...
# 33  butter,spinach,artichoke,cream cheese,sour cre...
# 34  spinach,artichoke,garlic,mayonnaise,cream chee...
# 35  olive,onion,green onion,garlic,spinach,parsley...
# 36  spinach,artichoke,garlic,mayonnaise,cream chee...
# 37  spinach,artichoke,garlic,mayonnaise,cream chee...
# 38  pasta,spinach,cheese,onion,olive,salad dressin...
#
#                                            directions  \
# 0   Preheat oven to 350 degrees F (175 degrees C)....
# 1   Preheat oven to 325 degrees F (165 degrees C)....
# 2   Preheat oven to 350 degrees F (175 degrees C)....
# 3   Preheat oven to 375 degrees F (190 degrees C)....
# 4   Melt butter in a large saucepan over medium he...
# 5   Preheat oven to 350 degrees F (175 degrees C)....
# 6   'Preheat oven to 350 degrees F (175 degrees C)...
# 7   Preheat oven to 350 degrees F (175 degrees C)....
# 8   In a large pot of salted boiling water, cook p...
# 9   Preheat oven to 350 degrees F (175 degrees C)....
# 10  Preheat oven to 375 degrees F (190 degrees C)....
# 11  Preheat oven to 375 degrees F (190 degrees C)....
# 12  Preheat oven to 350 degrees F (175 degrees C)....
# 13  Preheat oven to 375 degrees F (190 degrees C)....
# 14  Preheat oven to 325 degrees F (165 degrees C)....
# 15  'Preheat oven to 350 degrees F (175 degrees C)...
# 16  Preheat oven to 375 degrees F (190 degrees C)....
# 17  'Preheat oven to 350 degrees F (175 degrees C)...
# 18  Preheat oven to 350 degrees F (175 degrees C)....
# 19  Preheat oven to 350 degrees F (175 degrees C)....
# 20  In a large pot of salted boiling water, cook p...
# 21  Preheat oven to 400 degrees F (200 degrees C)....
# 22  Preheat oven according to pizza crust package ...
# 23  Preheat oven to 350 degrees F (175 degrees C)....
# 24  Preheat oven according to pizza crust package ...
# 25  Preheat oven to 400 degrees F (200 degrees C)....
# 26  Preheat oven to 325 degrees F (165 degrees C)....
# 27  Preheat oven to 375 degrees F (190 degrees C)....
# 28  In a large pot of salted boiling water, cook p...
# 29  Preheat oven according to pizza crust package ...
# 30  Preheat oven to 400 degrees F (200 degrees C)....
# 31  In a large pot over high heat, combine the spi...
# 32  Melt butter in a large saucepan over medium he...
# 33  Melt butter in a large saucepan over medium he...
# 34  Preheat oven to 375 degrees F (190 degrees C)....
# 35  Preheat oven to 350 degrees F (175 degrees C)....
# 36  Preheat oven to 375 degrees F (190 degrees C)....
# 37  Preheat oven to 375 degrees F (190 degrees C)....
# 38  In a large pot of salted boiling water, cook p...
#
#                                         url  \
# 0   https://www.allrecipes.com/recipe/20876
# 1   https://www.allrecipes.com/recipe/21686
# 2   https://www.allrecipes.com/recipe/12221
# 3   https://www.allrecipes.com/recipe/23783
# 4   https://www.allrecipes.com/recipe/26699
# 5   https://www.allrecipes.com/recipe/12221
# 6   https://www.allrecipes.com/recipe/24242
# 7   https://www.allrecipes.com/recipe/20876
# 8   https://www.allrecipes.com/recipe/14440
# 9   https://www.allrecipes.com/recipe/26819
# 10  https://www.allrecipes.com/recipe/15141
# 11  https://www.allrecipes.com/recipe/23783
# 12  https://www.allrecipes.com/recipe/26819
# 13  https://www.allrecipes.com/recipe/15141
# 14  https://www.allrecipes.com/recipe/21686
# 15  https://www.allrecipes.com/recipe/24242
# 16  https://www.allrecipes.com/recipe/15141
# 17  https://www.allrecipes.com/recipe/24242
# 18  https://www.allrecipes.com/recipe/26819
# 19  https://www.allrecipes.com/recipe/12221
# 20  https://www.allrecipes.com/recipe/14440
# 21  https://www.allrecipes.com/recipe/24915
# 22  https://www.allrecipes.com/recipe/24368
# 23  https://www.allrecipes.com/recipe/18417
# 24  https://www.allrecipes.com/recipe/24368
# 25  https://www.allrecipes.com/recipe/24915
# 26  https://www.allrecipes.com/recipe/21686
# 27  https://www.allrecipes.com/recipe/23783
# 28  https://www.allrecipes.com/recipe/14440
# 29  https://www.allrecipes.com/recipe/24368
# 30  https://www.allrecipes.com/recipe/24915
# 31  https://www.allrecipes.com/recipe/16332
# 32  https://www.allrecipes.com/recipe/26699
# 33  https://www.allrecipes.com/recipe/26699
# 34  https://www.allrecipes.com/recipe/14930
# 35  https://www.allrecipes.com/recipe/18417
# 36  https://www.allrecipes.com/recipe/14930
# 37  https://www.allrecipes.com/recipe/14930
# 38  https://www.allrecipes.com/recipe/16142
#
#                                             photo_url
# 0   https://images.media-allrecipes.com/userphotos...
# 1   https://images.media-allrecipes.com/userphotos...
# 2   https://images.media-allrecipes.com/userphotos...
# 3   https://images.media-allrecipes.com/userphotos...
# 4   https://images.media-allrecipes.com/userphotos...
# 5   https://images.media-allrecipes.com/userphotos...
# 6   https://images.media-allrecipes.com/userphotos...
# 7   https://images.media-allrecipes.com/userphotos...
# 8   https://images.media-allrecipes.com/userphotos...
# 9   https://images.media-allrecipes.com/userphotos...
# 10  https://images.media-allrecipes.com/userphotos...
# 11  https://images.media-allrecipes.com/userphotos...
# 12  https://images.media-allrecipes.com/userphotos...
# 13  https://images.media-allrecipes.com/userphotos...
# 14  https://images.media-allrecipes.com/userphotos...
# 15  https://images.media-allrecipes.com/userphotos...
# 16  https://images.media-allrecipes.com/userphotos...
# 17  https://images.media-allrecipes.com/userphotos...
# 18  https://images.media-allrecipes.com/userphotos...
# 19  https://images.media-allrecipes.com/userphotos...
# 20  https://images.media-allrecipes.com/userphotos...
# 21  https://images.media-allrecipes.com/userphotos...
# 22  https://images.media-allrecipes.com/userphotos...
# 23  https://images.media-allrecipes.com/userphotos...
# 24  https://images.media-allrecipes.com/userphotos...
# 25  https://images.media-allrecipes.com/userphotos...
# 26  https://images.media-allrecipes.com/userphotos...
# 27  https://images.media-allrecipes.com/userphotos...
# 28  https://images.media-allrecipes.com/userphotos...
# 29  https://images.media-allrecipes.com/userphotos...
# 30  https://images.media-allrecipes.com/userphotos...
# 31  https://images.media-allrecipes.com/userphotos...
# 32  https://images.media-allrecipes.com/userphotos...
# 33  https://images.media-allrecipes.com/userphotos...
# 34  https://images.media-allrecipes.com/userphotos...
# 35  https://images.media-allrecipes.com/userphotos...
# 36  https://images.media-allrecipes.com/userphotos...
# 37  https://images.media-allrecipes.com/userphotos...
# 38  https://images.media-allrecipes.com/userphotos...

# %% [markdown]
# ## Save the Model

# %%
import pickle
filename = 'model/recipEeze_recommender_model_SMALL.sav'
pickle.dump(item_based_recommender, open(filename, 'wb'))

# %%
rr_model = pickle.load(open(filename, 'rb'))

# %%
cross_validate(rr_model, data, measures=['RMSE', 'MAE'], cv=5, verbose=True)
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9071  0.9070  0.9061  0.9060  0.9066  0.9066  0.0004
# MAE (testset)     0.6266  0.6249  0.6253  0.6253  0.6251  0.6254  0.0006
# Fit time          22.56   24.01   21.76   22.46   25.57   23.27   1.36
# Test time         16.98   17.87   18.30   15.50   18.73   17.48   1.15
# {'test_rmse': array([0.9071256 , 0.90697745, 0.90610662, 0.90600469, 0.90660522]),
#  'test_mae': array([0.62662526, 0.62488307, 0.62527877, 0.62525857, 0.62507525]),
#  'fit_time': (22.558342695236206,
#   24.009589433670044,
#   21.762155532836914,
#   22.45959758758545,
#   25.570380926132202),
#  'test_time': (16.97546100616455,
#   17.86919665336609,
#   18.300251483917236,
#   15.498399496078491,
#   18.733608961105347)}
